# %%
import panel as pn
from main import app


app.servable()

# %%
# Célula de Teste e Inspeção do Dia 6
from dao.relatorios_dao import obter_df_engajamento_grupos, obter_df_status_encontros

print("📊 Relatório 1: Engajamento dos Grupos (Membro A)")
df_engajamento = obter_df_engajamento_grupos()
display(df_engajamento) 

print("\n-------------------------------------------------\n")

print("📈 Relatório 2: Status dos Encontros (Membro B)")
df_status = obter_df_status_encontros()
display(df_status)
# Out:
# 📊 Relatório 1: Engajamento dos Grupos (Membro A)
# 2026-06-13 09:40:47,706 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2026-06-13 09:40:47,707 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-06-13 09:40:47,711 INFO sqlalchemy.engine.Engine select current_schema()
# 2026-06-13 09:40:47,712 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-06-13 09:40:47,714 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2026-06-13 09:40:47,715 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-06-13 09:40:47,720 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-06-13 09:40:47,722 INFO sqlalchemy.engine.Engine
#         SELECT
#             g.nome AS "Nome do Grupo",
#             COUNT(DISTINCT e.id_encontro) AS "Total de Encontros",
#             COUNT(DISTINCT m.id_mensagem) AS "Total de Mensagens"
#         FROM grupo g
#         LEFT JOIN encontro e ON g.id_grupo = e.id_grupo
#         LEFT JOIN mensagem m ON g.id_grupo = e.id_grupo
#         GROUP BY g.nome
# ...
